# %% [markdown]
# # Luiz Henrique dos Santos Faleiros
# # GU3003825

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import math
from scipy.stats import norm
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics

# %% [markdown]
# Criando as datas para numeros

# %%
months = {'jan': 1, 'feb': 2, 'mar':3, 'apr': 4, 'may':5,'jun':6,'jul':7,'aug':8,'sep':9,'oct':10,'nov':11,'dec':12}
day_of_week = {'mon':0,'tue':1,'wed':2,'thu':3,'fri':4,'sat':5,'sun':6}

# %%
ff = pd.read_csv('forestfires.csv')

# %%
ff.head()
# Out:
#    X  Y month  day  FFMC   DMC     DC  ISI  temp  RH  wind  rain  area
# 0  7  5   mar  fri  86.2  26.2   94.3  5.1   8.2  51   6.7   0.0   0.0
# 1  7  4   oct  tue  90.6  35.4  669.1  6.7  18.0  33   0.9   0.0   0.0
# 2  7  4   oct  sat  90.6  43.7  686.9  6.7  14.6  33   1.3   0.0   0.0
# 3  8  6   mar  fri  91.7  33.3   77.5  9.0   8.3  97   4.0   0.2   0.0
# 4  8  6   mar  sun  89.3  51.3  102.2  9.6  11.4  99   1.8   0.0   0.0

# %%
ff['month'] = ff['month'].map(months)

# %%
ff['day'] = ff['day'].map(day_of_week)

# %%
ff.isna().sum()
# Out:
# X        0
# Y        0
# month    0
# day      0
# FFMC     0
# DMC      0
# DC       0
# ISI      0
# temp     0
# RH       0
# wind     0
# rain     0
# area     0
# dtype: int64

# %%
ff = ff[ff['area'] > 0]

# %%
ff['BUI'] = (0.8*ff['DMC']*ff['DC'])/(ff['DMC']+ 0.4*ff['DC'])

# %%
ff['area'] = ff['area'].map(lambda x: math.log(x))

# %%
ff
# Out:
#      X  Y  month  day  FFMC    DMC     DC   ISI  temp  RH  wind  rain  \
# 138  9  9      7    1  85.8   48.3  313.4   3.9  18.0  42   2.7   0.0
# 139  1  4      9    1  91.0  129.5  692.6   7.0  21.7  38   2.2   0.0
# 140  2  5      9    0  90.9  126.5  686.5   7.0  21.9  39   1.8   0.0
# 141  1  2      8    2  95.5   99.9  513.3  13.2  23.3  31   4.5   0.0
# 142  8  6      8    4  90.1  108.0  529.8  12.5  21.2  51   8.9   0.0
# ..  .. ..    ...  ...   ...    ...    ...   ...   ...  ..   ...   ...
# 509  5  4      8    4  91.0  166.9  752.6   7.1  21.1  71   7.6   1.4
# 510  6  5      8    4  91.0  166.9  752.6   7.1  18.2  62   5.4   0.0
# 512  4  3      8    6  81.6   56.7  665.6   1.9  27.8  32   2.7   0.0
# 513  2  4      8    6  81.6   56.7  665.6   1.9  21.9  71   5.8   0.0
# 514  7  4      8    6  81.6   56.7  665.6   1.9  21.2  70   6.7   0.0
#
#          area         BUI
# 138 -1.021651   69.732673
# 139 -0.843970  176.497663
# 140 -0.755023  173.208178
# 141 -0.597837  134.404482
# 142 -0.494296  143.081770
# ..        ...         ...
# 509  0.774727  214.743668
# 510 -0.843970  214.743668
# 512  1.862529   93.489862
# 513  3.994340   93.489862
# 514  2.412336   93.489862
#
# [270 rows x 14 columns]

# %%
countplot = sns.countplot(x=ff['month'])
countplot.set(xlabel="Meses", ylabel="Queimadas")
# Out:
# [Text(0.5, 0, 'Meses'), Text(0, 0.5, 'Queimadas')]

# %%
strip = sns.stripplot(x='month', y='temp', data=ff,palette='rainbow')
strip.set(xlabel="Meses", ylabel="Temperatura")
# Out:
# [Text(0.5, 0, 'Meses'), Text(0, 0.5, 'Temperatura')]

# %%
sns.stripplot(x='month',y='DMC',data=ff,palette='Set1')
# Out:
# <AxesSubplot:xlabel='month', ylabel='DMC'>

# %%
sns.stripplot(x='month',y='FFMC',data=ff,palette='Set1')
# Out:
# <AxesSubplot:xlabel='month', ylabel='FFMC'>

# %%
sns.stripplot(x='month',y='BUI',data=ff,palette='Set1')
# Out:
# <AxesSubplot:xlabel='month', ylabel='BUI'>

# %%
sns.stripplot(x='month',y='DC',data=ff,palette='Set1')
# Out:
# <AxesSubplot:xlabel='month', ylabel='DC'>

# %%
sns.heatmap(ff.corr(), cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(ff)

# %%
ff.columns
# Out:
# Index(['X', 'Y', 'month', 'day', 'FFMC', 'DMC', 'DC', 'ISI', 'temp', 'RH',
#        'wind', 'rain', 'area', 'BUI'],
#       dtype='object')

# %%
x = ff[['X', 'Y', 'month', 'day', 'FFMC', 'DMC', 'DC', 'ISI', 'RH',
       'wind', 'rain', 'area', 'BUI']]
y = ff['temp']

# %%
x_train, x_teste, y_train, y_test = train_test_split(x,y,test_size=0.3, random_state=110)

# %%
lm = LinearRegression()

# %%
lm.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
print(lm.intercept_)
# Out:
# 33.39259814987163

# %%
print(lm.coef_)
# Out:
# [-0.03694974  0.23088343 -1.00108476  0.36212309 -0.12308926 -0.00307621
#   0.01231972  0.43567828 -0.21070651 -0.55935348  1.61355768 -0.17569574
#   0.02595073]

# %%
coeficiente = pd.DataFrame(lm.coef_,x.columns, columns=['Coeficiente'])

# %%
coeficiente
# Out:
#        Coeficiente
# X        -0.036950
# Y         0.230883
# month    -1.001085
# day       0.362123
# FFMC     -0.123089
# DMC      -0.003076
# DC        0.012320
# ISI       0.435678
# RH       -0.210707
# wind     -0.559353
# rain      1.613558
# area     -0.175696
# BUI       0.025951

# %%
predict = lm.predict(x_teste)

# %%
plt.figure(figsize=(12,6))
plt.scatter(y_test, predict)

# %%
sns.displot((y_test-predict), rug=True, kde=True)

# %%
print('MAE', metrics.mean_absolute_error(y_test,predict))

# %%
print('MSE', metrics.mean_squared_error(y_test,predict))

# %%
print('RMSE', np.sqrt(metrics.mean_squared_error(y_test,predict)))
